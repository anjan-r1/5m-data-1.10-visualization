# %% [markdown]
# # Assignment

# %% [markdown]
# ## Thanks for visiting!!

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Question 1
#
# Question: How do you create a 2x2 subplot grid in matplotlib and select the first subplot?

# %%
fig, ax = plt.subplots(2, 2)  # ax is a 2D array

ax[0, 0].plot([1, 2, 3], [4, 5, 6], marker='o')

plt.show()

# %% [markdown]
# ### Question 2
#
# Question: How to plot a line and set the color to red and style to dash in a matplotlib plot?
#
# x = [1, 2, 3, 4]
#
# y = [1, 4, 9, 16]

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

fig, ax = plt.subplots(1, 1)
ax.plot(x,y, "v--r");

# %% [markdown]
# ### Question 3
#
# Question: How to plot a histogram with 30 bins for `data` in matplotlib?
#
# data = np.random.randn(1000)

# %%
data = np.random.randn(1000)
fig, ax = plt.subplots(1, 1)
ax.hist(data, bins=30)
fig.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# ### Question 4
#
# Question: How can you set the x-axis and y-axis labels in a matplotlib plot?

# %%
fig, ax = plt.subplots(1, 1)
ax.hist(data, bins=30)
ax.set_xlabel("Values")
ax.set_ylabel("Density")
fig.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# ### Question 5
#
# Question: How do you create a bar plot in seaborn using the `tips` dataset to show the average tip amount per day?

# %%
import seaborn as sns
from matplotlib.ticker import MultipleLocator

tips = sns.load_dataset("tips")
print(tips.groupby("day")["tip"].mean())

plt.figure(figsize=(6, 8))
sns.barplot(x="day", y="tip", data=tips, orient="v")
plt.gca().yaxis.set_major_locator(MultipleLocator(0.1))
# Out:
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %% [markdown]
# ### Question 6
#
# Question: How to create a box plot for total_bill categorized by day in the `tips` dataset using seaborn?

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

tips = pd.read_csv("/Users/anjan/5m-data-1.10-visualization/data/tips.csv")

sns.catplot(x="total_bill", y="day", kind="box", data=tips, order=["Thur", "Fri", "Sat", "Sun"])

# %% [markdown]
# ## Thanks for reviewing!!
